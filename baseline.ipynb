# %% [markdown]
# # Setup

# %%
# !pip install flaml
# !pip install h2o
# Out:
# Collecting flaml
#   Downloading FLAML-2.1.1-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.10/dist-packages (from flaml) (1.23.5)
# Installing collected packages: flaml
# Successfully installed flaml-2.1.1

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from xgboost import XGBRegressor

# %% [markdown]
# # Data Loading & EDA

# %%
train = pd.read_csv('/content/drive/MyDrive/ME /SinoPac/30_Training Dataset_V2/training_data_v1104v2.csv')
testpub = pd.read_csv('/content/drive/MyDrive/ME /SinoPac/public test/public_dataset_v1104v3.csv')
testprv = pd.read_csv('/content/drive/MyDrive/ME /SinoPac/private test/private_dataset_v3.csv')
subpub = pd.read_csv('/content/drive/MyDrive/ME /SinoPac/public_submission_template.csv')
subprv = pd.read_csv('/content/drive/MyDrive/ME /SinoPac/private_submission_template.csv')
subpubprv = pd.read_csv('/content/drive/MyDrive/ME /SinoPac/public_private_submission_template.csv')

# %%
print('train:', train.shape)
print('public test :', testpub.shape)
print('private test:', testprv.shape)
print('public sub  :', subpub.shape)
print('public sub  :', subprv.shape)
print('pubic_private sub :', subpubprv.shape)
# Out:
# train: (11751, 39)
# public test : (5876, 38)
# private test: (5875, 38)
# public sub  : (5876, 2)
# public sub  : (5875, 2)
# pubic_private sub : (11751, 2)

# %%
# Change column name
df_train = train.copy()
df_testpub = testpub.copy()
df_testprv = testprv.copy()

column_name_mapping = {
    '縣市': 'County',
    '鄉鎮市區': 'District',
    '路名': 'Road',
    '土地面積': 'Land Area',
    '使用分區': 'Use Partitions',
    '移轉層次': 'Floor Level',
    '總樓層數': 'Total Floors',
    '主要用途': 'Main Purpose',
    '主要建材': 'Main Materials',
    '建物型態': 'Building Type',
    '屋齡': 'House Age',
    '建物面積': 'Building Area',
    '車位面積': 'Parking Area',
    '車位個數': 'Num of Parking',
    '橫坐標': 'x-axis',
    '縱坐標': 'y-axis',
    '主建物面積': 'Main Building Area',
    '陽台面積': 'Balcony Area',
    '附屬建物面積': 'Ancillary Building Area',
    '單價': 'Price'
}

df_train.rename(columns=column_name_mapping, inplace=True)
df_testpub.rename(columns=column_name_mapping, inplace=True)
df_testprv.rename(columns=column_name_mapping, inplace=True)

# %% [markdown]
# # Data Preprocessing

# %%
df_train = df_train.drop(['備註'], axis=1)
df_testpub = df_testpub.drop(['備註'], axis=1)
df_testprv = df_testprv.drop(['備註'], axis=1)

print('train:', df_train.shape)
print('public test :', df_testpub.shape)
print('private test:', df_testprv.shape)
# Out:
# train: (11751, 38)
# public test : (5876, 37)
# private test: (5875, 37)

# %%
df_train = pd.DataFrame(df_train)
df_testpub = pd.DataFrame(df_testpub)
df_testprv = pd.DataFrame(df_testprv)

df_train['ID'] = df_train['ID'].apply(lambda x: int(x.replace('TR-', '')) if isinstance(x, str) and x.startswith('TR-') else x)
df_testpub['ID'] = df_testpub['ID'].apply(lambda x: int(x.replace('PU-', '')) if isinstance(x, str) and x.startswith('PU-') else x)
df_testprv['ID'] = df_testprv['ID'].apply(lambda x: int(x.replace('PR-', '')) if isinstance(x, str) and x.startswith('PR-') else x)

# %%
numeric_features = ['Land Area', 'Floor Level', 'Total Floors', 'House Age', 'Building Area', 'Parking Area', 'Num of Parking', 'Main Building Area',
                    'Balcony Area', 'Ancillary Building Area']
train_numeric = df_train[numeric_features]
testpub_numeric = df_testpub[numeric_features]

scaler = StandardScaler()
train_scaled = scaler.fit_transform(train_numeric)
testpub_scaled = scaler.transform(testpub_numeric)

df_train[numeric_features] = train_scaled
df_testpub[numeric_features] = testpub_scaled

# %%
label_encoder = LabelEncoder()
object_columns = df_train.select_dtypes(include=['object']).columns

for column in object_columns:
    combined_data = pd.concat([df_train[column], df_testpub[column], df_testprv[column]], axis=0)
    label_encoder.fit(combined_data)

    df_train[column] = label_encoder.transform(df_train[column])
    df_testpub[column] = label_encoder.transform(df_testpub[column])
    df_testprv[column] = label_encoder.transform(df_testprv[column])

# %%
# finding correlation of every variables with target
correlation_matrix = df_train.corr()
correlation_with_target = correlation_matrix['Price']
print(correlation_with_target)
# Out:
# ID                                -0.002611
# County                            -0.459016
# District                          -0.236772
# Road                              -0.035864
# Land Area                          0.067088
# Use Partitions                     0.008904
# Floor Level                        0.054038
# Total Floors                       0.037874
# Main Purpose                      -0.057103
# Main Materials                     0.011903
# Building Type                      0.016075
# House Age                          0.049196
# Building Area                      0.061327
# Parking Area                       0.099986
# Num of Parking                     0.013064
# x-axis                             0.455633
# y-axis                             0.394402
# Main Building Area                 0.056150
# Balcony Area                       0.009866
# Ancillary Building Area            0.064905
# Price                              1.000000
# lng                                0.456070
# lat                                0.394313
# ATM Count within 10km              0.667817
# Bank Count within 10km             0.689029
# Nearest Metro Distance (km)       -0.248423
# Nearest Bic Distance (km)         -0.083310
# Nearest shop Distance (km)        -0.122372
# Shop Count within 1km              0.530947
# Nearest medical Distance (km)     -0.172773
# University Count within 10km       0.579513
# Snhigh school Count within 10km    0.697673
# Jnhighschool Count within 10km     0.665184
# Primschool Count within 10km       0.676527
# Nearest uni Distance (km)         -0.254273
# Nearest hs Distance (km)          -0.300269
# Nearest ms Distance (km)          -0.200491
# Nearest ss Distance (km)          -0.207361
# Name: Price, dtype: float64

# %%
df2_train = df_train.copy()
df2_testpub = df_testpub.copy()
df2_testprv = df_testprv.copy()

df2_train = df2_train.drop(['ID', 'Use Partitions', 'Balcony Area'], axis=1)
df2_testpub = df2_testpub.drop(['ID', 'Use Partitions', 'Balcony Area'], axis=1)
df2_testprv = df2_testprv.drop(['ID', 'Use Partitions', 'Balcony Area'], axis=1)

print('train:', df2_train.shape)
print('public test :', df2_testpub.shape)
print('private test:', df2_testprv.shape)
# Out:
# train: (11751, 35)
# public test : (5876, 34)
# private test: (5875, 34)

# %%
# Data Spliting
X = df2_train.drop('Price', axis=1)
y = df2_train['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05, random_state = 42)

# %% [markdown]
# # Model Training

# %%
# Linear Regression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred = model.predict(X_test)

train_mape_lr = mean_absolute_percentage_error(y_train, y_pred_train)
test_mape_lr = mean_absolute_percentage_error(y_test, y_pred)

print('train mape: {:.4f}'.format(train_mape_lr * 100))
print('test mape: {:.4f}'.format(test_mape_lr * 100))
# Out:
# train mape: 18.2111
# test mape: 18.1659

# %%
# XGBoost
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

mape_scorer = make_scorer(mean_absolute_percentage_error, greater_is_better=False)
model = XGBRegressor()

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring=mape_scorer,
    cv=10
)

grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

y_pred_train_best = best_model.predict(X_train)
y_pred_best = best_model.predict(X_test)

train_mape_xgb = mean_absolute_percentage_error(y_train, y_pred_train_best)
test_mape_xgb = mean_absolute_percentage_error(y_test, y_pred_best)

print('train mape: {:.4f}'.format(train_mape_xgb * 100))
print('test mape: {:.4f}'.format(test_mape_xgb * 100))
# Out:
# train mape: 4.5596
# test mape: 9.4585

# %% [markdown]
# ## H2O

# %%
# H2O
import h2o
h2o.init()
from h2o.automl import H2OAutoML
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.20.1" 2023-08-24; OpenJDK Runtime Environment (build 11.0.20.1+1-post-Ubuntu-0ubuntu122.04); OpenJDK 64-Bit Server VM (build 11.0.20.1+1-post-Ubuntu-0ubuntu122.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpcawq7vgr
#   JVM stdout: /tmp/tmpcawq7vgr/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpcawq7vgr/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         05 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.2
# H2O_cluster_version_age:    3 days
# H2O_cluster_name:           H2O_from_python_unknownUser_68qvok
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.170 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
trainframe = h2o.H2OFrame(df2_train)
testframe = h2o.H2OFrame(df_testpub)
trainf, testf, validf = trainframe.split_frame([0.6, 0.2], seed=42)
y = 'Price'
X = list(trainframe.columns)
X.remove(y)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
aml = H2OAutoML(max_models=100, max_runtime_secs=3600, seed=42)
aml.train(x=X, y=y, training_frame=trainf)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OGradientBoostingEstimator : Gradient Boosting Machine
# Model Key: GBM_grid_1_AutoML_1_20231111_101638_model_5
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     61                 61                          163760                 9            9            9             57            340           209.082
#
# ModelMetricsRegression: gbm
# ** Reported on train data. **
#
# MSE: 0.01655740286848341
# RMSE: 0.12867557215137382
# MAE: 0.08586615514243484
# RMSLE: 0.03859280953210337
# Mean Residual Deviance: 0.01655740286848341
#
# ModelMetricsRegression: gbm
# ** Reported on cross-validation data. **
#
# MSE: 0.09621740690220275
# RMSE: 0.3101893081687419
# MAE: 0.1843218926321196
# RMSLE: 0.08016850460298218
# Mean Residual Deviance: 0.09621740690220275
#
# Cross-Validation Metrics Summary:
#                         mean       sd          cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ----------  ------------  ------------  ------------  ------------  ------------
# mae                     0.184282   0.00553039  0.178384      0.178892      0.191282      0.186034      0.186819
# mean_residual_deviance  0.0963063  0.0565354   0.0682675     0.0618734     0.0869792     0.0683753     0.196036
# mse                     0.0963063  0.0565354   0.0682675     0.0618734     0.0869792     0.0683753     0.196036
# r2                      0.90458    0.0462143   0.921582      0.932965      0.919916      0.926034      0.822404
# residual_deviance       0.0963063  0.0565354   0.0682675     0.0618734     0.0869792     0.0683753     0.196036
# rmse                    0.301839   0.0806209   0.26128       0.248744      0.294922      0.261487      0.44276
# rmsle                   0.0801725  0.00477828  0.0756773     0.0757299     0.0805111     0.0817984     0.0871457
#
# Scoring History:
#     timestamp            duration          number_of_trees    training_rmse    training_mae    training_deviance
# --  -------------------  ----------------  -----------------  ---------------  --------------  -------------------
#     2023-11-11 10:38:33  1 min 49.788 sec  0                  0.991006         0.730004        0.982094
#     2023-11-11 10:38:33  1 min 49.975 sec  5                  0.633492         0.455314        0.401312
#     2023-11-11 10:38:33  1 min 50.153 sec  10                 0.427939         0.29834         0.183131
#     2023-11-11 10:38:33  1 min 50.331 sec  15                 0.314907         0.210129        0.0991664
#     2023-11-11 10:38:34  1 min 50.507 sec  20                 0.24841          0.161032        0.0617074
#     2023-11-11 10:38:34  1 min 50.700 sec  25                 0.210353         0.133511        0.0442483
#     2023-11-11 10:38:34  1 min 50.878 sec  30                 0.186876         0.117639        0.0349228
#     2023-11-11 10:38:34  1 min 51.039 sec  35                 0.170585         0.107366        0.0290994
#     2023-11-11 10:38:34  1 min 51.201 sec  40                 0.158388         0.100647        0.0250866
#     2023-11-11 10:38:34  1 min 51.350 sec  45                 0.149043         0.0962129       0.0222137
#     2023-11-11 10:38:35  1 min 51.502 sec  50                 0.14232          0.0922485       0.020255
#     2023-11-11 10:38:35  1 min 51.652 sec  55                 0.13538          0.0886849       0.0183277
#     2023-11-11 10:38:35  1 min 51.797 sec  60                 0.130074         0.0865043       0.0169192
#     2023-11-11 10:38:35  1 min 51.828 sec  61                 0.128676         0.0858662       0.0165574
#
# Variable Importances:
# variable                         relative_importance    scaled_importance      percentage
# -------------------------------  ---------------------  ---------------------  ----------------------
# Snhigh school Count within 10km  10381.306640625        1.0                    0.3036047788599982
# Bank Count within 10km           4483.04345703125       0.43183807320437184    0.13110810271854104
# County                           2690.781494140625      0.2591948766459545     0.07869280320573953
# House Age                        2357.386962890625      0.22707998564125836    0.06894256882414582
# x-axis                           1705.946044921875      0.1643286441656606     0.04989096167227872
# Jnhighschool Count within 10km   1372.9154052734375     0.1322488057428946     0.040151369422070385
# lng                              1371.3763427734375     0.13210055248795488    0.040106359025389136
# ATM Count within 10km            1192.0511474609375     0.11482669655437235    0.03486193381461434
# Primschool Count within 10km     908.9412231445312      0.08755557027740479    0.026582289552032515
# Nearest Metro Distance (km)      802.0043334960938      0.0772546617934994     0.02345488450971934
# ---                              ---                    ---                    ---
# Road                             144.2959747314453      0.01389959662368263    0.004219983959176343
# Num of Parking                   140.3529815673828      0.01351977996855827    0.004104669807589967
# University Count within 10km     136.66705322265625     0.013164725593196454   0.003996873602474969
# Nearest hs Distance (km)         99.6763916015625       0.009601526575806988   0.0029150693527662764
# Nearest medical Distance (km)    92.85210418701172      0.008944163524045718   0.0027154907888055626
# Nearest ss Distance (km)         74.3551025390625       0.007162403068616611   0.0021745397997535187
# Main Purpose                     60.41202163696289      0.005819308082140017   0.0017667697433963203
# Nearest shop Distance (km)       60.26408386230469      0.00580505768189856    0.001762443253782346
# Ancillary Building Area          41.05379104614258      0.003954588036681956   0.00120063182635922
# Use Partitions                   6.68447208404541       0.0006438950621000995  0.00019548961793794555
# [36 rows x 4 columns]
#
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
def MAPE(actual, predict):
  abs_pct_error = abs((actual - predict) / actual)
  mape = abs_pct_error.mean()[0]
  return mape

train_mape_h2o = MAPE(trainf[y], aml.predict(trainf))
test_mape_h2o = MAPE(testf[y], aml.predict(testf))

print("train mape: " + str(round(train_mape_h2o, 4)*100))
print("test mape: " + str(round(test_mape_h2o, 4)*100))
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# train mape: 4.859999999999999
# test mape: 10.05

# %% [markdown]
# ## FLAML

# %%
from flaml import AutoML
from flaml.automl.data import get_output_from_log
flaml = AutoML()

# %%
# Define hyperparameters
settings = {
    "time_budget": 3600,  # total running time in seconds
    "metric": 'mape',
    "task": 'regression',
    "log_file_name": 'airlines_experiment.log',
}

flaml.fit(X_train = X_train, y_train = y_train, **settings)
# Out:
# [flaml.automl.logger: 11-13 12:13:40] {1679} INFO - task = regression
# [flaml.automl.logger: 11-13 12:13:40] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 11-13 12:13:40] {1788} INFO - Minimizing error metric: mape
# [flaml.automl.logger: 11-13 12:13:40] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 11-13 12:13:40] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:41] {2344} INFO - Estimated sufficient time budget=3770s. Estimated necessary time budget=27s.
# [flaml.automl.logger: 11-13 12:13:41] {2391} INFO -  at 0.5s,	estimator lgbm's best error=0.3404,	best estimator lgbm's best error=0.3404
# [flaml.automl.logger: 11-13 12:13:41] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:41] {2391} INFO -  at 0.9s,	estimator lgbm's best error=0.3404,	best estimator lgbm's best error=0.3404
# [flaml.automl.logger: 11-13 12:13:41] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:41] {2391} INFO -  at 1.3s,	estimator lgbm's best error=0.2566,	best estimator lgbm's best error=0.2566
# [flaml.automl.logger: 11-13 12:13:41] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 11-13 12:13:42] {2391} INFO -  at 1.7s,	estimator xgboost's best error=0.3405,	best estimator lgbm's best error=0.2566
# [flaml.automl.logger: 11-13 12:13:42] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:42] {2391} INFO -  at 2.2s,	estimator lgbm's best error=0.1494,	best estimator lgbm's best error=0.1494
# [flaml.automl.logger: 11-13 12:13:42] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:43] {2391} INFO -  at 2.6s,	estimator lgbm's best error=0.1494,	best estimator lgbm's best error=0.1494
# [flaml.automl.logger: 11-13 12:13:43] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:43] {2391} INFO -  at 3.0s,	estimator lgbm's best error=0.1412,	best estimator lgbm's best error=0.1412
# [flaml.automl.logger: 11-13 12:13:43] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:43] {2391} INFO -  at 3.5s,	estimator lgbm's best error=0.1412,	best estimator lgbm's best error=0.1412
# [flaml.automl.logger: 11-13 12:13:43] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:44] {2391} INFO -  at 3.9s,	estimator lgbm's best error=0.1412,	best estimator lgbm's best error=0.1412
# [flaml.automl.logger: 11-13 12:13:44] {2218} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:44] {2391} INFO -  at 4.4s,	estimator lgbm's best error=0.1251,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:44] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 11-13 12:13:45] {2391} INFO -  at 4.8s,	estimator xgboost's best error=0.3405,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:45] {2218} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 11-13 12:13:45] {2391} INFO -  at 5.4s,	estimator extra_tree's best error=0.2463,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:45] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 11-13 12:13:46] {2391} INFO -  at 6.0s,	estimator extra_tree's best error=0.1841,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:46] {2218} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 11-13 12:13:47] {2391} INFO -  at 7.4s,	estimator rf's best error=0.2447,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:47] {2218} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 11-13 12:13:49] {2391} INFO -  at 9.2s,	estimator rf's best error=0.1688,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:49] {2218} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 11-13 12:13:50] {2391} INFO -  at 9.6s,	estimator extra_tree's best error=0.1841,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:50] {2218} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:52] {2391} INFO -  at 11.6s,	estimator lgbm's best error=0.1251,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:52] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 11-13 12:13:52] {2391} INFO -  at 12.5s,	estimator extra_tree's best error=0.1574,	best estimator lgbm's best error=0.1251
# [flaml.automl.logger: 11-13 12:13:52] {2218} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 11-13 12:13:56] {2391} INFO -  at 16.4s,	estimator lgbm's best error=0.1016,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:13:56] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 11-13 12:13:57] {2391} INFO -  at 16.8s,	estimator xgboost's best error=0.2604,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:13:57] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 11-13 12:13:58] {2391} INFO -  at 17.7s,	estimator rf's best error=0.1688,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:13:58] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 11-13 12:13:58] {2391} INFO -  at 18.2s,	estimator xgboost's best error=0.1744,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:13:58] {2218} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 11-13 12:14:01] {2391} INFO -  at 20.7s,	estimator rf's best error=0.1440,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:01] {2218} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 11-13 12:14:01] {2391} INFO -  at 21.1s,	estimator xgboost's best error=0.1744,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:01] {2218} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 11-13 12:14:02] {2391} INFO -  at 21.5s,	estimator xgboost's best error=0.1744,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:02] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:02] {2391} INFO -  at 22.1s,	estimator extra_tree's best error=0.1311,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:02] {2218} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 11-13 12:14:03] {2391} INFO -  at 22.6s,	estimator xgboost's best error=0.1513,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:03] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:03] {2391} INFO -  at 23.2s,	estimator extra_tree's best error=0.1311,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:03] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:04] {2391} INFO -  at 23.9s,	estimator extra_tree's best error=0.1140,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:04] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:04] {2391} INFO -  at 24.5s,	estimator extra_tree's best error=0.1140,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:04] {2218} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 11-13 12:14:12] {2391} INFO -  at 32.2s,	estimator lgbm's best error=0.1016,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:12] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 11-13 12:14:13] {2391} INFO -  at 33.5s,	estimator lgbm's best error=0.1016,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:13] {2218} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 11-13 12:14:16] {2391} INFO -  at 36.0s,	estimator rf's best error=0.1192,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:16] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:17] {2391} INFO -  at 37.2s,	estimator extra_tree's best error=0.1049,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:17] {2218} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 11-13 12:14:19] {2391} INFO -  at 38.7s,	estimator lgbm's best error=0.1016,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:19] {2218} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 11-13 12:14:19] {2391} INFO -  at 39.3s,	estimator xgboost's best error=0.1439,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:19] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:20] {2391} INFO -  at 39.9s,	estimator extra_tree's best error=0.1049,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:20] {2218} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:21] {2391} INFO -  at 40.8s,	estimator extra_tree's best error=0.1023,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:21] {2218} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:21] {2391} INFO -  at 41.3s,	estimator extra_tree's best error=0.1023,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:21] {2218} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 11-13 12:14:24] {2391} INFO -  at 43.5s,	estimator xgboost's best error=0.1436,	best estimator lgbm's best error=0.1016
# [flaml.automl.logger: 11-13 12:14:24] {2218} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:27] {2391} INFO -  at 47.4s,	estimator extra_tree's best error=0.0949,	best estimator extra_tree's best error=0.0949
# [flaml.automl.logger: 11-13 12:14:27] {2218} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:29] {2391} INFO -  at 48.7s,	estimator extra_tree's best error=0.0949,	best estimator extra_tree's best error=0.0949
# [flaml.automl.logger: 11-13 12:14:29] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 11-13 12:14:31] {2391} INFO -  at 50.7s,	estimator lgbm's best error=0.0980,	best estimator extra_tree's best error=0.0949
# [flaml.automl.logger: 11-13 12:14:31] {2218} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:35] {2391} INFO -  at 55.1s,	estimator extra_tree's best error=0.0930,	best estimator extra_tree's best error=0.0930
# [flaml.automl.logger: 11-13 12:14:35] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:37] {2391} INFO -  at 57.0s,	estimator extra_tree's best error=0.0930,	best estimator extra_tree's best error=0.0930
# [flaml.automl.logger: 11-13 12:14:37] {2218} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 11-13 12:14:50] {2391} INFO -  at 69.5s,	estimator extra_tree's best error=0.0915,	best estimator extra_tree's best error=0.0915
# [flaml.automl.logger: 11-13 12:14:50] {2218} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 11-13 12:14:52] {2391} INFO -  at 72.3s,	estimator rf's best error=0.1192,	best estimator extra_tree's best error=0.0915
# [flaml.automl.logger: 11-13 12:14:52] {2218} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 11-13 12:15:16] {2391} INFO -  at 95.7s,	estimator extra_tree's best error=0.0907,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:16] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 11-13 12:15:24] {2391} INFO -  at 104.3s,	estimator lgbm's best error=0.0980,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:24] {2218} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 11-13 12:15:27] {2391} INFO -  at 107.0s,	estimator rf's best error=0.1073,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:27] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 11-13 12:15:38] {2391} INFO -  at 118.5s,	estimator extra_tree's best error=0.0907,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:38] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 11-13 12:15:41] {2391} INFO -  at 121.1s,	estimator rf's best error=0.1073,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:41] {2218} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 11-13 12:15:47] {2391} INFO -  at 126.7s,	estimator rf's best error=0.0991,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:47] {2218} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 11-13 12:15:50] {2391} INFO -  at 129.6s,	estimator rf's best error=0.0991,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:50] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 11-13 12:15:55] {2391} INFO -  at 135.0s,	estimator lgbm's best error=0.0980,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:15:55] {2218} INFO - iteration 55, current learner extra_tree
# [flaml.automl.logger: 11-13 12:16:37] {2391} INFO -  at 176.8s,	estimator extra_tree's best error=0.0907,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:37] {2218} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 11-13 12:16:40] {2391} INFO -  at 179.9s,	estimator rf's best error=0.0991,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:40] {2218} INFO - iteration 57, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:16:41] {2391} INFO -  at 180.9s,	estimator xgb_limitdepth's best error=0.1110,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:41] {2218} INFO - iteration 58, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:16:42] {2391} INFO -  at 181.7s,	estimator xgb_limitdepth's best error=0.1110,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:42] {2218} INFO - iteration 59, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:16:45] {2391} INFO -  at 184.8s,	estimator xgb_limitdepth's best error=0.1110,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:45] {2218} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 11-13 12:16:57] {2391} INFO -  at 197.2s,	estimator rf's best error=0.0991,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:57] {2218} INFO - iteration 61, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:16:58] {2391} INFO -  at 197.8s,	estimator xgb_limitdepth's best error=0.1110,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:16:58] {2218} INFO - iteration 62, current learner extra_tree
# [flaml.automl.logger: 11-13 12:17:10] {2391} INFO -  at 210.4s,	estimator extra_tree's best error=0.0907,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:10] {2218} INFO - iteration 63, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:17:12] {2391} INFO -  at 211.7s,	estimator xgb_limitdepth's best error=0.1110,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:12] {2218} INFO - iteration 64, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:17:12] {2391} INFO -  at 212.3s,	estimator xgb_limitdepth's best error=0.1110,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:12] {2218} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 11-13 12:17:15] {2391} INFO -  at 214.9s,	estimator rf's best error=0.0991,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:15] {2218} INFO - iteration 66, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 12:17:16] {2391} INFO -  at 216.4s,	estimator xgb_limitdepth's best error=0.1109,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:16] {2218} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 11-13 12:17:29] {2391} INFO -  at 229.2s,	estimator extra_tree's best error=0.0907,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:29] {2218} INFO - iteration 68, current learner rf
# [flaml.automl.logger: 11-13 12:17:46] {2391} INFO -  at 246.5s,	estimator rf's best error=0.0946,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:46] {2218} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 11-13 12:17:59] {2391} INFO -  at 259.3s,	estimator lgbm's best error=0.0968,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:17:59] {2218} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 11-13 12:18:06] {2391} INFO -  at 266.1s,	estimator rf's best error=0.0946,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:18:06] {2218} INFO - iteration 71, current learner extra_tree
# [flaml.automl.logger: 11-13 12:18:47] {2391} INFO -  at 306.7s,	estimator extra_tree's best error=0.0907,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:18:47] {2218} INFO - iteration 72, current learner rf
# [flaml.automl.logger: 11-13 12:19:19] {2391} INFO -  at 339.4s,	estimator rf's best error=0.0934,	best estimator extra_tree's best error=0.0907
# [flaml.automl.logger: 11-13 12:19:19] {2218} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 11-13 12:19:52] {2391} INFO -  at 372.4s,	estimator extra_tree's best error=0.0904,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:52] {2218} INFO - iteration 74, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:53] {2391} INFO -  at 373.1s,	estimator xgboost's best error=0.1213,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:53] {2218} INFO - iteration 75, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:54] {2391} INFO -  at 373.6s,	estimator xgboost's best error=0.1213,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:54] {2218} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:54] {2391} INFO -  at 374.1s,	estimator xgboost's best error=0.1213,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:54] {2218} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:55] {2391} INFO -  at 375.1s,	estimator xgboost's best error=0.1109,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:55] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:56] {2391} INFO -  at 375.8s,	estimator xgboost's best error=0.1109,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:56] {2218} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:57] {2391} INFO -  at 377.0s,	estimator xgboost's best error=0.1109,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:57] {2218} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 11-13 12:19:58] {2391} INFO -  at 377.7s,	estimator xgboost's best error=0.1109,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:19:58] {2218} INFO - iteration 81, current learner extra_tree
# [flaml.automl.logger: 11-13 12:20:19] {2391} INFO -  at 398.8s,	estimator extra_tree's best error=0.0904,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:20:19] {2218} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 11-13 12:20:25] {2391} INFO -  at 404.7s,	estimator xgboost's best error=0.1084,	best estimator extra_tree's best error=0.0904
# [flaml.automl.logger: 11-13 12:20:25] {2218} INFO - iteration 83, current learner extra_tree
# [flaml.automl.logger: 11-13 12:21:30] {2391} INFO -  at 470.0s,	estimator extra_tree's best error=0.0899,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:21:30] {2218} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 11-13 12:21:56] {2391} INFO -  at 496.1s,	estimator extra_tree's best error=0.0899,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:21:56] {2218} INFO - iteration 85, current learner extra_tree
# [flaml.automl.logger: 11-13 12:22:51] {2391} INFO -  at 550.7s,	estimator extra_tree's best error=0.0899,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:22:51] {2218} INFO - iteration 86, current learner extra_tree
# [flaml.automl.logger: 11-13 12:23:39] {2391} INFO -  at 599.0s,	estimator extra_tree's best error=0.0899,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:23:39] {2218} INFO - iteration 87, current learner extra_tree
# [flaml.automl.logger: 11-13 12:24:05] {2391} INFO -  at 625.4s,	estimator extra_tree's best error=0.0899,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:24:05] {2218} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 11-13 12:24:06] {2391} INFO -  at 626.2s,	estimator xgboost's best error=0.1084,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:24:06] {2218} INFO - iteration 89, current learner rf
# [flaml.automl.logger: 11-13 12:24:19] {2391} INFO -  at 639.0s,	estimator rf's best error=0.0934,	best estimator extra_tree's best error=0.0899
# [flaml.automl.logger: 11-13 12:24:19] {2218} INFO - iteration 90, current learner extra_tree
# [flaml.automl.logger: 11-13 12:26:09] {2391} INFO -  at 748.8s,	estimator extra_tree's best error=0.0898,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:26:09] {2218} INFO - iteration 91, current learner xgboost
# [flaml.automl.logger: 11-13 12:26:15] {2391} INFO -  at 754.9s,	estimator xgboost's best error=0.0968,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:26:15] {2218} INFO - iteration 92, current learner xgboost
# [flaml.automl.logger: 11-13 12:26:16] {2391} INFO -  at 755.9s,	estimator xgboost's best error=0.0968,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:26:16] {2218} INFO - iteration 93, current learner xgboost
# [flaml.automl.logger: 11-13 12:26:53] {2391} INFO -  at 792.8s,	estimator xgboost's best error=0.0917,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:26:53] {2218} INFO - iteration 94, current learner xgboost
# [flaml.automl.logger: 11-13 12:27:17] {2391} INFO -  at 817.4s,	estimator xgboost's best error=0.0917,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:27:17] {2218} INFO - iteration 95, current learner rf
# [flaml.automl.logger: 11-13 12:28:34] {2391} INFO -  at 893.9s,	estimator rf's best error=0.0925,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:28:34] {2218} INFO - iteration 96, current learner extra_tree
# [flaml.automl.logger: 11-13 12:30:17] {2391} INFO -  at 997.4s,	estimator extra_tree's best error=0.0898,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:30:17] {2218} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 11-13 12:31:26] {2391} INFO -  at 1065.7s,	estimator xgboost's best error=0.0911,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:31:26] {2218} INFO - iteration 98, current learner xgboost
# [flaml.automl.logger: 11-13 12:31:59] {2391} INFO -  at 1098.8s,	estimator xgboost's best error=0.0911,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:31:59] {2218} INFO - iteration 99, current learner rf
# [flaml.automl.logger: 11-13 12:34:26] {2391} INFO -  at 1245.9s,	estimator rf's best error=0.0923,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:34:26] {2218} INFO - iteration 100, current learner lgbm
# [flaml.automl.logger: 11-13 12:34:28] {2391} INFO -  at 1247.9s,	estimator lgbm's best error=0.0968,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:34:28] {2218} INFO - iteration 101, current learner extra_tree
# [flaml.automl.logger: 11-13 12:35:46] {2391} INFO -  at 1326.1s,	estimator extra_tree's best error=0.0898,	best estimator extra_tree's best error=0.0898
# [flaml.automl.logger: 11-13 12:35:46] {2218} INFO - iteration 102, current learner extra_tree
# [flaml.automl.logger: 11-13 12:39:37] {2391} INFO -  at 1556.9s,	estimator extra_tree's best error=0.0897,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:39:37] {2218} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 11-13 12:39:42] {2391} INFO -  at 1561.9s,	estimator lgbm's best error=0.0968,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:39:42] {2218} INFO - iteration 104, current learner xgboost
# [flaml.automl.logger: 11-13 12:40:47] {2391} INFO -  at 1626.9s,	estimator xgboost's best error=0.0911,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:40:47] {2218} INFO - iteration 105, current learner lgbm
# [flaml.automl.logger: 11-13 12:41:11] {2391} INFO -  at 1650.5s,	estimator lgbm's best error=0.0968,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:41:11] {2218} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 11-13 12:42:23] {2391} INFO -  at 1722.6s,	estimator extra_tree's best error=0.0897,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:42:23] {2218} INFO - iteration 107, current learner extra_tree
# [flaml.automl.logger: 11-13 12:43:52] {2391} INFO -  at 1812.0s,	estimator extra_tree's best error=0.0897,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:43:52] {2218} INFO - iteration 108, current learner xgboost
# [flaml.automl.logger: 11-13 12:44:02] {2391} INFO -  at 1821.9s,	estimator xgboost's best error=0.0911,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:44:02] {2218} INFO - iteration 109, current learner extra_tree
# [flaml.automl.logger: 11-13 12:51:51] {2391} INFO -  at 2291.1s,	estimator extra_tree's best error=0.0897,	best estimator extra_tree's best error=0.0897
# [flaml.automl.logger: 11-13 12:51:51] {2218} INFO - iteration 110, current learner extra_tree
# [flaml.automl.logger: 11-13 12:58:55] {2391} INFO -  at 2714.9s,	estimator extra_tree's best error=0.0896,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 12:58:55] {2218} INFO - iteration 111, current learner lgbm
# [flaml.automl.logger: 11-13 12:59:15] {2391} INFO -  at 2735.1s,	estimator lgbm's best error=0.0947,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 12:59:15] {2218} INFO - iteration 112, current learner extra_tree
# [flaml.automl.logger: 11-13 13:01:52] {2391} INFO -  at 2891.9s,	estimator extra_tree's best error=0.0896,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:01:52] {2218} INFO - iteration 113, current learner xgboost
# [flaml.automl.logger: 11-13 13:03:33] {2391} INFO -  at 2992.6s,	estimator xgboost's best error=0.0903,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:03:33] {2218} INFO - iteration 114, current learner xgb_limitdepth
# [flaml.automl.logger: 11-13 13:03:34] {2391} INFO -  at 2994.4s,	estimator xgb_limitdepth's best error=0.1109,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:03:34] {2218} INFO - iteration 115, current learner lgbm
# [flaml.automl.logger: 11-13 13:03:47] {2391} INFO -  at 3007.1s,	estimator lgbm's best error=0.0947,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:03:47] {2218} INFO - iteration 116, current learner lgbm
# [flaml.automl.logger: 11-13 13:04:03] {2391} INFO -  at 3023.5s,	estimator lgbm's best error=0.0947,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:04:03] {2218} INFO - iteration 117, current learner extra_tree
# [flaml.automl.logger: 11-13 13:12:49] {2391} INFO -  at 3549.5s,	estimator extra_tree's best error=0.0896,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:12:49] {2218} INFO - iteration 118, current learner lgbm
# [flaml.automl.logger: 11-13 13:13:16] {2391} INFO -  at 3575.7s,	estimator lgbm's best error=0.0947,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:13:16] {2218} INFO - iteration 119, current learner lgbm
# [flaml.automl.logger: 11-13 13:13:40] {2391} INFO -  at 3600.1s,	estimator lgbm's best error=0.0947,	best estimator extra_tree's best error=0.0896
# [flaml.automl.logger: 11-13 13:15:19] {2627} INFO - retrain extra_tree for 99.0s
# [flaml.automl.logger: 11-13 13:15:19] {2630} INFO - retrained model: ExtraTreesRegressor(max_features=0.9501703974045013, max_leaf_nodes=5580,
#                     n_estimators=1445, n_jobs=-1, random_state=12032022)
# [flaml.automl.logger: 11-13 13:15:19] {1930} INFO - fit succeeded
# [flaml.automl.logger: 11-13 13:15:19] {1931} INFO - Time taken to find the best model: 2714.8597633838654

# %%
from flaml.ml import sklearn_metric_loss_score
train_mape = sklearn_metric_loss_score('mape', flaml.predict(X_train), y_train)
test_mape = sklearn_metric_loss_score('mape', flaml.predict(X_test), y_test)

print('train mape: {:.4f}'.format(train_mape * 100))
print('test mape: {:.4f}'.format(test_mape * 100))
# Out:
# train mape: 0.7354
# test mape: 8.5191

# %% [markdown]
# # Test

# %%
subpub = pd.DataFrame(subpub)
pred = flaml.predict(df_testpub)
subpub['predicted_price'] = pred

# %%
datatp = h2o.H2OFrame(df_testpub)
pred = aml.leader.predict(datatp)
predd = pred.as_data_frame()
subpub['predicted_price'] = predd
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
subpub.to_csv('/content/drive/MyDrive/ME /SinoPac/submission_20.csv', index=False)
